# %%
#读取csv
import pandas as pd
data = pd.read_csv('data1.csv',index_col=0,header=0)

# %%
data.shape
# Out:
# (10000, 30)

# %%
y=data['y'] # 提取出survived 列
#X=data.drop(['id','y','six_optial_mp_num','six_optial_mp_avg_amt'],axis=1) # 提取除去这三列的其它所有列
X=data.drop(['y'],axis=1) # 提取除去这三列的其它所有列

# %% [markdown]
# #特征选择
# 参考文档：
# 自然语言处理学习笔记7：特征选择方法
# https://blog.csdn.net/weixin_41931602/article/details/80551801

# %%
#移除低方差的特征 (Removing features with low variance)  -例子
'''from sklearn.feature_selection import VarianceThreshold
X = [[0, 0, 1], [0, 1, 0], [1, 0, 0], [0, 1, 1], [0, 1, 0], [0, 1, 1]]
sel = VarianceThreshold(threshold=(.8 * (1 - .8)))
sel.fit_transform(X)
'''
# Out:
# 'from sklearn.feature_selection import VarianceThreshold\nX = [[0, 0, 1], [0, 1, 0], [1, 0, 0], [0, 1, 1], [0, 1, 0], [0, 1, 1]]\nsel = VarianceThreshold(threshold=(.8 * (1 - .8)))\nsel.fit_transform(X)\n'

# %%
from sklearn.feature_selection import VarianceThreshold
#X = [[0, 0, 1], [0, 1, 0], [1, 0, 0], [0, 1, 1], [0, 1, 0], [0, 1, 1]]
sel = VarianceThreshold(threshold=(.9 * (1 - .9))) 
new_X = sel.fit_transform(X,y)

# 找出需要删除的变量名
to_drop = []
for i in range(len(sel.get_support())):
    if sel.get_support()[i] == False:
        to_drop.append(X.keys()[i])

# %%
to_drop
# Out:
# []

# %%
new_X.shape
# Out:
# (10000, 29)

# %%
# 皮尔森系数
data.corr()  # pearson相关系数
data.corr('kendall') # Kendall Tau相关系数
data.corr('spearman') # spearman秩相关
# Out:
#                                y      city  mar_status       age  \
# y                       1.000000  0.013434    0.037279 -0.033585
# city                    0.013434  1.000000   -0.046353 -0.008494
# mar_status              0.037279 -0.046353    1.000000 -0.526181
# age                    -0.033585 -0.008494   -0.526181  1.000000
# xaccount_age           -0.036355 -0.069754    0.010124  0.215469
# cred_limit              0.060846 -0.061579   -0.130651  0.231954
# this_bill_rate          0.093524  0.069008   -0.038423 -0.044226
# this_bill_mp            0.077079  0.013678   -0.102287  0.113331
# last_mp_days           -0.358295 -0.010143   -0.028836 -0.036008
# six_bill_num           -0.017564 -0.027132   -0.005461  0.101480
# six_bill_avg_amt        0.037447  0.005674   -0.141730  0.202770
# six_cycle_mp_num        0.406396  0.012733    0.031390 -0.017684
# six_cycle_mp_avg_amt    0.370724  0.011160    0.020695 -0.006243
# six_bill_avg_debt_rate  0.050362  0.040090   -0.029140  0.039470
# six_bill_low_repay_num  0.133575 -0.018833    0.047950 -0.022577
# epp_nbr_12m             0.366994  0.024077   -0.004386  0.028028
# alop_nbr_12m            0.131367 -0.009639    0.012384 -0.012015
# epp_avg_amt_12m         0.333858  0.018429   -0.026986  0.058968
# alop_avg_amt_12m        0.129735 -0.008166    0.010277 -0.004714
# consume_num_session12   0.052728 -0.073152    0.075013 -0.009936
# consume_num_session6    0.060399 -0.079654    0.071922 -0.032199
# consume_num_session3    0.065503 -0.073635    0.067231 -0.041283
# consume_num_session     0.099142 -0.078830    0.052803 -0.044826
# consume_amt_session12   0.039279  0.000032   -0.124084  0.172797
# consume_amt_session6    0.046271  0.004474   -0.135222  0.153310
# consume_amt_session3    0.058681  0.012949   -0.134050  0.136108
# consume_amt_session     0.123010  0.013822   -0.116806  0.102198
# month_avg_use_year     -0.024205  0.080438   -0.044302 -0.062620
# month_avg_use_month6   -0.014773  0.075527   -0.046476 -0.056125
# month_avg_use_month3   -0.001145  0.073918   -0.046023 -0.044509
#
#                         xaccount_age  cred_limit  this_bill_rate  \
# y                          -0.036355    0.060846        0.093524
# city                       -0.069754   -0.061579        0.069008
# mar_status                  0.010124   -0.130651       -0.038423
# age                         0.215469    0.231954       -0.044226
# xaccount_age                1.000000    0.294537       -0.208875
# cred_limit                  0.294537    1.000000       -0.212165
# this_bill_rate             -0.208875   -0.212165        1.000000
# this_bill_mp                0.110522    0.497944        0.434239
# last_mp_days               -0.269024   -0.181724        0.132498
# six_bill_num                0.692605    0.174905       -0.145284
# six_bill_avg_amt            0.238365    0.674506        0.132258
# six_cycle_mp_num            0.064686    0.104448       -0.092504
# six_cycle_mp_avg_amt        0.070753    0.137404       -0.098642
# six_bill_avg_debt_rate      0.280987    0.450246        0.144988
# six_bill_low_repay_num      0.182890    0.038858       -0.345706
# epp_nbr_12m                 0.137644    0.183789       -0.100873
# alop_nbr_12m                0.020544    0.083971       -0.063795
# epp_avg_amt_12m             0.160310    0.266317       -0.107467
# alop_avg_amt_12m            0.033671    0.102975       -0.065180
# consume_num_session12       0.387987    0.286600        0.038425
# consume_num_session6        0.227136    0.262962        0.094635
# consume_num_session3        0.125949    0.242409        0.147203
# consume_num_session         0.039504    0.215226        0.232341
# consume_amt_session12       0.357146    0.615376        0.270816
# consume_amt_session6        0.203258    0.597889        0.363514
# consume_amt_session3        0.100404    0.555021        0.460280
# consume_amt_session         0.000946    0.453465        0.644705
# month_avg_use_year         -0.276029   -0.265814        0.733407
# month_avg_use_month6       -0.260827   -0.234915        0.766303
# month_avg_use_month3       -0.227803   -0.208462        0.813460
#
#                         this_bill_mp  last_mp_days  six_bill_num  \
# y                           0.077079     -0.358295     -0.017564
# city                        0.013678     -0.010143     -0.027132
# mar_status                 -0.102287     -0.028836     -0.005461
# age                         0.113331     -0.036008      0.101480
# xaccount_age                0.110522     -0.269024      0.692605
# cred_limit                  0.497944     -0.181724      0.174905
# this_bill_rate              0.434239      0.132498     -0.145284
# this_bill_mp                1.000000      0.068047      0.071787
# last_mp_days                0.068047      1.000000     -0.258653
# six_bill_num                0.071787     -0.258653      1.000000
# six_bill_avg_amt            0.730716     -0.123635      0.122363
# six_cycle_mp_num           -0.154179     -0.798485      0.122469
# six_cycle_mp_avg_amt       -0.133392     -0.793186      0.120077
# six_bill_avg_debt_rate      0.599884     -0.143347      0.164556
# six_bill_low_repay_num     -0.131950     -0.353839      0.238318
# epp_nbr_12m                -0.086778     -0.760386      0.222952
# alop_nbr_12m               -0.065918     -0.194430      0.060779
# epp_avg_amt_12m            -0.036158     -0.758730      0.225391
# alop_avg_amt_12m           -0.053517     -0.195852      0.068698
# consume_num_session12       0.209021     -0.188366      0.448027
# consume_num_session6        0.208865     -0.123505      0.298651
# consume_num_session3        0.219814     -0.063565      0.137123
# consume_num_session         0.237903      0.015592      0.008213
# consume_amt_session12       0.610052     -0.180921      0.403917
# consume_amt_session6        0.651531     -0.111016      0.259118
# consume_amt_session3        0.698734     -0.039953      0.112388
# consume_amt_session         0.764695      0.049721     -0.013666
# month_avg_use_year          0.282721      0.189371     -0.195113
# month_avg_use_month6        0.314827      0.195541     -0.197735
# month_avg_use_month3        0.362175      0.203362     -0.173084
#
#                                 ...           consume_num_session6  \
# y                               ...                       0.060399
# city                            ...                      -0.079654
# mar_status                      ...                       0.071922
# age                             ...                      -0.032199
# xaccount_age                    ...                       0.227136
# cred_limit                      ...                       0.262962
# this_bill_rate                  ...                       0.094635
# this_bill_mp                    ...                       0.208865
# last_mp_days                    ...                      -0.123505
# six_bill_num                    ...                       0.298651
# six_bill_avg_amt                ...                       0.145966
# six_cycle_mp_num                ...                       0.108966
# six_cycle_mp_avg_amt            ...                       0.103577
# six_bill_avg_debt_rate          ...                       0.102769
# six_bill_low_repay_num          ...                      -0.191705
# epp_nbr_12m                     ...                       0.125855
# alop_nbr_12m                    ...                       0.009551
# epp_avg_amt_12m                 ...                       0.117459
# alop_avg_amt_12m                ...                       0.012305
# consume_num_session12           ...                       0.934336
# consume_num_session6            ...                       1.000000
# consume_num_session3            ...                       0.928954
# consume_num_session             ...                       0.778839
# consume_amt_session12           ...                       0.458915
# consume_amt_session6            ...                       0.456378
# consume_amt_session3            ...                       0.402681
# consume_amt_session             ...                       0.321579
# month_avg_use_year              ...                       0.109503
# month_avg_use_month6            ...                       0.143835
# month_avg_use_month3            ...                       0.151911
#
#                         consume_num_session3  consume_num_session  \
# y                                   0.065503             0.099142
# city                               -0.073635            -0.078830
# mar_status                          0.067231             0.052803
# age                                -0.041283            -0.044826
# xaccount_age                        0.125949             0.039504
# cred_limit                          0.242409             0.215226
# this_bill_rate                      0.147203             0.232341
# this_bill_mp                        0.219814             0.237903
# last_mp_days                       -0.063565             0.015592
# six_bill_num                        0.137123             0.008213
# six_bill_avg_amt                    0.125009             0.080077
# six_cycle_mp_num                    0.061741            -0.002218
# six_cycle_mp_avg_amt                0.055954            -0.008002
# six_bill_avg_debt_rate              0.073979             0.028138
# six_bill_low_repay_num             -0.240891            -0.270570
# epp_nbr_12m                         0.068173             0.003066
# alop_nbr_12m                       -0.015411            -0.039912
# epp_avg_amt_12m                     0.060141            -0.005724
# alop_avg_amt_12m                   -0.012985            -0.037596
# consume_num_session12               0.833443             0.682213
# consume_num_session6                0.928954             0.778839
# consume_num_session3                1.000000             0.870122
# consume_num_session                 0.870122             1.000000
# consume_amt_session12               0.382950             0.283533
# consume_amt_session6                0.404231             0.316843
# consume_amt_session3                0.422758             0.354480
# consume_amt_session                 0.365316             0.448062
# month_avg_use_year                  0.137801             0.141499
# month_avg_use_month6                0.173649             0.174191
# month_avg_use_month3                0.220180             0.215266
#
#                         consume_amt_session12  consume_amt_session6  \
# y                                    0.039279              0.046271
# city                                 0.000032              0.004474
# mar_status                          -0.124084             -0.135222
# age                                  0.172797              0.153310
# xaccount_age                         0.357146              0.203258
# cred_limit                           0.615376              0.597889
# this_bill_rate                       0.270816              0.363514
# this_bill_mp                         0.610052              0.651531
# last_mp_days                        -0.180921             -0.111016
# six_bill_num                         0.403917              0.259118
# six_bill_avg_amt                     0.684407              0.701130
# six_cycle_mp_num                     0.090784              0.075680
# six_cycle_mp_avg_amt                 0.119679              0.108376
# six_bill_avg_debt_rate               0.535620              0.535926
# six_bill_low_repay_num              -0.128714             -0.216241
# epp_nbr_12m                          0.205181              0.147455
# alop_nbr_12m                         0.027168              0.008030
# epp_avg_amt_12m                      0.273415              0.213274
# alop_avg_amt_12m                     0.044446              0.023180
# consume_num_session12                0.532042              0.452059
# consume_num_session6                 0.458915              0.456378
# consume_num_session3                 0.382950              0.404231
# consume_num_session                  0.283533              0.316843
# consume_amt_session12                1.000000              0.940861
# consume_amt_session6                 0.940861              1.000000
# consume_amt_session3                 0.848709              0.931803
# consume_amt_session                  0.672665              0.759729
# month_avg_use_year                   0.367114              0.433589
# month_avg_use_month6                 0.365510              0.489248
# month_avg_use_month3                 0.356915              0.472864
#
#                         consume_amt_session3  consume_amt_session  \
# y                                   0.058681             0.123010
# city                                0.012949             0.013822
# mar_status                         -0.134050            -0.116806
# age                                 0.136108             0.102198
# xaccount_age                        0.100404             0.000946
# cred_limit                          0.555021             0.453465
# this_bill_rate                      0.460280             0.644705
# this_bill_mp                        0.698734             0.764695
# last_mp_days                       -0.039953             0.049721
# six_bill_num                        0.112388            -0.013666
# six_bill_avg_amt                    0.670321             0.542913
# six_cycle_mp_num                    0.010077            -0.062248
# six_cycle_mp_avg_amt                0.038183            -0.046462
# six_bill_avg_debt_rate              0.505613             0.402008
# six_bill_low_repay_num             -0.282219            -0.316743
# epp_nbr_12m                         0.078638             0.001397
# alop_nbr_12m                       -0.013816            -0.043274
# epp_avg_amt_12m                     0.137572             0.042013
# alop_avg_amt_12m                    0.000476            -0.031984
# consume_num_session12               0.373309             0.278039
# consume_num_session6                0.402681             0.321579
# consume_num_session3                0.422758             0.365316
# consume_num_session                 0.354480             0.448062
# consume_amt_session12               0.848709             0.672665
# consume_amt_session6                0.931803             0.759729
# consume_amt_session3                1.000000             0.843455
# consume_amt_session                 0.843455             1.000000
# month_avg_use_year                  0.474255             0.460822
# month_avg_use_month6                0.530900             0.508476
# month_avg_use_month3                0.597445             0.571017
#
#                         month_avg_use_year  month_avg_use_month6  \
# y                                -0.024205             -0.014773
# city                              0.080438              0.075527
# mar_status                       -0.044302             -0.046476
# age                              -0.062620             -0.056125
# xaccount_age                     -0.276029             -0.260827
# cred_limit                       -0.265814             -0.234915
# this_bill_rate                    0.733407              0.766303
# this_bill_mp                      0.282721              0.314827
# last_mp_days                      0.189371              0.195541
# six_bill_num                     -0.195113             -0.197735
# six_bill_avg_amt                  0.164196              0.192293
# six_cycle_mp_num                 -0.127054             -0.129239
# six_cycle_mp_avg_amt             -0.122014             -0.121252
# six_bill_avg_debt_rate            0.162522              0.188224
# six_bill_low_repay_num           -0.414987             -0.443298
# epp_nbr_12m                      -0.146222             -0.155814
# alop_nbr_12m                     -0.121930             -0.120269
# epp_avg_amt_12m                  -0.143009             -0.152009
# alop_avg_amt_12m                 -0.122329             -0.120699
# consume_num_session12             0.064434              0.069424
# consume_num_session6              0.109503              0.143835
# consume_num_session3              0.137801              0.173649
# consume_num_session               0.141499              0.174191
# consume_amt_session12             0.367114              0.365510
# consume_amt_session6              0.433589              0.489248
# consume_amt_session3              0.474255              0.530900
# consume_amt_session               0.460822              0.508476
# month_avg_use_year                1.000000              0.960865
# month_avg_use_month6              0.960865              1.000000
# month_avg_use_month3              0.900805              0.944101
#
#                         month_avg_use_month3
# y                                  -0.001145
# city                                0.073918
# mar_status                         -0.046023
# age                                -0.044509
# xaccount_age                       -0.227803
# cred_limit                         -0.208462
# this_bill_rate                      0.813460
# this_bill_mp                        0.362175
# last_mp_days                        0.203362
# six_bill_num                       -0.173084
# six_bill_avg_amt                    0.182569
# six_cycle_mp_num                   -0.165393
# six_cycle_mp_avg_amt               -0.161554
# six_bill_avg_debt_rate              0.178352
# six_bill_low_repay_num             -0.443639
# epp_nbr_12m                        -0.163867
# alop_nbr_12m                       -0.115891
# epp_avg_amt_12m                    -0.162261
# alop_avg_amt_12m                   -0.115289
# consume_num_session12               0.082690
# consume_num_session6                0.151911
# consume_num_session3                0.220180
# consume_num_session                 0.215266
# consume_amt_session12               0.356915
# consume_amt_session6                0.472864
# consume_amt_session3                0.597445
# consume_amt_session                 0.571017
# month_avg_use_year                  0.900805
# month_avg_use_month6                0.944101
# month_avg_use_month3                1.000000
#
# [30 rows x 30 columns]

# %%
from sklearn.cross_validation import cross_val_score, ShuffleSplit
from sklearn.datasets import load_boston
from sklearn.ensemble import RandomForestRegressor
import numpy as np
from sklearn.linear_model import LinearRegression

# Load boston housing dataset as an example
#boston = load_boston()
#X = boston["data"]
#Y = boston["target"]
#names = boston["feature_names"]

y=data['y'] # 提取出survived 列
#X=data.drop(['id','y','six_optial_mp_num','six_optial_mp_avg_amt'],axis=1) # 提取除去这三列的其它所有列
X=data.drop(['y'],axis=1) # 提取除去这三列的其它所有列
X=data.drop(['city'],axis=1) # 提取除去这三列的其它所有列
names=data.drop(['y'],axis=1).columns

#这里要注意的是，上面的scores都是负数，为什么均方误差会出现负数的情况呢？
#因为这里的mean_squared_error是一种损失函数，优化的目标的使其最小化，而分类准确率是一种奖励函数，优化的目标是使其最大化。
lm = LinearRegression()
scores = cross_val_score(lm, X, y, cv=10, scoring='mean_squared_error')
print(scores)


#rf = RandomForestRegressor(n_estimators=20, max_depth=4)
#scores = []
## 单独采用每个特征进行建模，并进行交叉验证
#for i in range(X.shape[1]):
#    score = cross_val_score(rf, X[:, i:i+1], Y, scoring="r2",  # 注意X[:, i]和X[:, i:i+1]的区别
#                            cv=ShuffleSplit(len(X), 3, .3))
#    scores.append((format(np.mean(score), '.3f'), names[i]))
#print(sorted(scores, reverse=True))
# Out:
# [-0.04118164 -0.04712487 -0.05254028 -0.05156609 -0.0571801  -0.05331802
#  -0.04644757 -0.05321006 -0.56937612 -0.56479942]
# C:\Users\hxm\AppData\Roaming\Python\Python36\site-packages\sklearn\metrics\scorer.py:100: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# C:\Users\hxm\AppData\Roaming\Python\Python36\site-packages\sklearn\metrics\scorer.py:100: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# C:\Users\hxm\AppData\Roaming\Python\Python36\site-packages\sklearn\metrics\scorer.py:100: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# C:\Users\hxm\AppData\Roaming\Python\Python36\site-packages\sklearn\metrics\scorer.py:100: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# C:\Users\hxm\AppData\Roaming\Python\Python36\site-packages\sklearn\metrics\scorer.py:100: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# C:\Users\hxm\AppData\Roaming\Python\Python36\site-packages\sklearn\metrics\scorer.py:100: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# C:\Users\hxm\AppData\Roaming\Python\Python36\site-packages\sklearn\metrics\scorer.py:100: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# C:\Users\hxm\AppData\Roaming\Python\Python36\site-packages\sklearn\metrics\scorer.py:100: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# C:\Users\hxm\AppData\Roaming\Python\Python36\site-packages\sklearn\metrics\scorer.py:100: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)
# C:\Users\hxm\AppData\Roaming\Python\Python36\site-packages\sklearn\metrics\scorer.py:100: DeprecationWarning: Scoring method mean_squared_error was renamed to neg_mean_squared_error in version 0.18 and will be removed in 0.20.
#   sample_weight=sample_weight)

# %%
names=data.drop(['y'],axis=1).columns

# %%
names
# Out:
# Index(['city', 'mar_status', 'age', 'xaccount_age', 'cred_limit',
#        'this_bill_rate', 'this_bill_mp', 'last_mp_days', 'six_bill_num',
#        'six_bill_avg_amt', 'six_cycle_mp_num', 'six_cycle_mp_avg_amt',
#        'six_bill_avg_debt_rate', 'six_bill_low_repay_num', 'epp_nbr_12m',
#        'alop_nbr_12m', 'epp_avg_amt_12m', 'alop_avg_amt_12m',
#        'consume_num_session12', 'consume_num_session6', 'consume_num_session3',
#        'consume_num_session', 'consume_amt_session12', 'consume_amt_session6',
#        'consume_amt_session3', 'consume_amt_session', 'month_avg_use_year',
#        'month_avg_use_month6', 'month_avg_use_month3'],
#       dtype='object')

# %%
X.shape[1]
# Out:
# 29

# %%
'''特征变量选择(排序)对于数据分析、机器学习从业者来说非常重要。
好的特征选择能够提升模型的性能，更能帮助我们理解数据的特点、底层结构，
这对进一步改善模型、算法都有着重要作用。至于Python的变量选择代码实现可以参考结合Scikit-learn介绍几种常用的特征选择方法。

在本文中，我们采用信用评分模型的变量选择方法，
通过WOE分析方法，即是通过比较指标分箱和对应分箱的违约概率来确定指标是否符合经济意义。
首先我们对变量进行离散化（分箱）处理。

'''
#https://www.jianshu.com/p/f931a4df202c

# %%
import pandas as pd
import numpy as np
from pandas import Series,DataFrame
import scipy.stats.stats as stats
import matplotlib.pyplot as plt
import statsmodels.api as sm
import math

# 定义自动分箱函数
def mono_bin(Y, X, n = 20):
    r = 0
    good=Y.sum()
    bad=Y.count()-good
    while np.abs(r) < 1:
        d1 = pd.DataFrame({"X": X, "Y": Y, "Bucket": pd.qcut(X, n)})
        d2 = d1.groupby('Bucket', as_index = True)
        r, p = stats.spearmanr(d2.mean().X, d2.mean().Y)
        n = n - 1
    d3 = pd.DataFrame(d2.X.min(), columns = ['min'])
    d3['min']=d2.min().X
    d3['max'] = d2.max().X
    d3['sum'] = d2.sum().Y
    d3['total'] = d2.count().Y
    d3['rate'] = d2.mean().Y
    d3['woe']=np.log((d3['rate']/(1-d3['rate']))/(good/bad))
    d3['goodattribute']=d3['sum']/good
    d3['badattribute']=(d3['total']-d3['sum'])/bad
    iv=((d3['goodattribute']-d3['badattribute'])*d3['woe']).sum()
    d4 = (d3.sort_index(by = 'min'))
    print("=" * 60)
    print(d4)
    cut=[]
    cut.append(float('-inf'))
    for i in range(1,n+1):
        qua=X.quantile(i/(n+1))
        cut.append(round(qua,4))
    cut.append(float('inf'))
    woe=list(d4['woe'].round(3))
    return d4,iv,cut,woe
#自定义分箱函数
def self_bin(Y,X,cat):
    good=Y.sum()
    bad=Y.count()-good
    d1=pd.DataFrame({'X':X,'Y':Y,'Bucket':pd.cut(X,cat)})
    d2=d1.groupby('Bucket', as_index = True)
    d3 = pd.DataFrame(d2.X.min(), columns=['min'])
    d3['min'] = d2.min().X
    d3['max'] = d2.max().X
    d3['sum'] = d2.sum().Y
    d3['total'] = d2.count().Y
    d3['rate'] = d2.mean().Y
    d3['woe'] = np.log((d3['rate'] / (1 - d3['rate'])) / (good / bad))
    d3['goodattribute'] = d3['sum'] / good
    d3['badattribute'] = (d3['total'] - d3['sum']) / bad
    iv = ((d3['goodattribute'] - d3['badattribute']) * d3['woe']).sum()
    d4 = (d3.sort_index(by='min'))
    print("=" * 60)
    print(d4)
    woe = list(d4['woe'].round(3))
    return d4, iv,woe
#用woe代替
def replace_woe(series,cut,woe):
    list=[]
    i=0
    while i<len(series):
        value=series[i]
        j=len(cut)-2
        m=len(cut)-2
        while j>=0:
            if value>=cut[j]:
                j=-1
            else:
                j -=1
                m -= 1
        list.append(woe[m])
        i += 1
    return list
#计算分数函数
def get_score(coe,woe,factor):
    scores=[]
    for w in woe:
        score=round(coe*w*factor,0)
        scores.append(score)
    return scores

#根据变量计算分数
def compute_score(series,cut,score):
    list = []
    i = 0
    while i < len(series):
        value = series[i]
        j = len(cut) - 2
        m = len(cut) - 2
        while j >= 0:
            if value >= cut[j]:
                j = -1
            else:
                j -= 1
                m -= 1
        list.append(score[m])
        i += 1
    return list

# %%
    pinf = float('inf')#正无穷大
    ninf = float('-inf')#负无穷大

# %%
X.columns
# Out:
# Index(['city', 'mar_status', 'age', 'xaccount_age', 'cred_limit',
#        'this_bill_rate', 'this_bill_mp', 'last_mp_days', 'six_bill_num',
#        'six_bill_avg_amt', 'six_cycle_mp_num', 'six_cycle_mp_avg_amt',
#        'six_bill_avg_debt_rate', 'six_bill_low_repay_num', 'epp_nbr_12m',
#        'alop_nbr_12m', 'epp_avg_amt_12m', 'alop_avg_amt_12m',
#        'consume_num_session12', 'consume_num_session6', 'consume_num_session3',
#        'consume_num_session', 'consume_amt_session12', 'consume_amt_session6',
#        'consume_amt_session3', 'consume_amt_session', 'month_avg_use_year',
#        'month_avg_use_month6', 'month_avg_use_month3'],
#       dtype='object')
