# %%
import pandas as pd
import numpy as np
#加载数据
#cvs

df = pd.read_csv('data.csv')

# %%
df.columns
# Out:
# Index(['id', 'y', 'city', 'mar_status', 'age', 'xaccount_age', 'cred_limit',
#        'this_bill_rate', 'this_bill_mp', 'last_mp_days', 'six_bill_num',
#        'six_bill_avg_amt', 'six_cycle_mp_num', 'six_cycle_mp_avg_amt',
#        'six_bill_avg_debt_rate', 'six_bill_low_repay_num', 'six_optial_mp_num',
#        'six_optial_mp_avg_amt', 'epp_nbr_12m', 'alop_nbr_12m',
#        'epp_avg_amt_12m', 'alop_avg_amt_12m', 'consume_num_session12',
#        'consume_num_session6', 'consume_num_session3', 'consume_num_session',
#        'consume_amt_session12', 'consume_amt_session6', 'consume_amt_session3',
#        'consume_amt_session', 'month_avg_use_year', 'month_avg_use_month6',
#        'month_avg_use_month3'],
#       dtype='object')

# %%
#规格化
#方法1
s = (df['consume_num_session3'] - df['consume_num_session3'].min())/(df['consume_num_session3'].max() - df['consume_num_session3'].min())
#方法2
#s = (df['month_avg_use_month6'] - df['month_avg_use_month6'].mean()/(df['month_avg_use_month6'].std()))
#标准化处理
#df1=(df-df.mean(axis=0))/(df.std(axis=0))
#'''#标准差算法2-归一 探索，结果不好
#df2=(df-df.min())/(df.max()-df.min())'''

# %%
df['consume_num_session3'].mean()
# Out:
# 22.3463

# %%
s.std()
# Out:
# 0.05058496469367015

# %%
#安全删除，如果用del是永久删除
df2 = df
#df2 = df.drop(['month_avg_use_month6'],axis=1)

#把规格化的那一列插入到数组中,最开始的14是我把他插到了第15lie
df2['month_avg_use_month6_std2']=s
#df2.insert(14,'month_avg_use_month6_std',s)

#print（df2.columns[13:15]）

# %%
df2.columns
# Out:
# Index(['id', 'y', 'city', 'mar_status', 'age', 'xaccount_age', 'cred_limit',
#        'this_bill_rate', 'this_bill_mp', 'last_mp_days', 'six_bill_num',
#        'six_bill_avg_amt', 'six_cycle_mp_num', 'six_cycle_mp_avg_amt',
#        'month_avg_use_month6_std', 'six_bill_avg_debt_rate',
#        'six_bill_low_repay_num', 'six_optial_mp_num', 'six_optial_mp_avg_amt',
#        'epp_nbr_12m', 'alop_nbr_12m', 'epp_avg_amt_12m', 'alop_avg_amt_12m',
#        'consume_num_session12', 'consume_num_session6', 'consume_num_session3',
#        'consume_num_session', 'consume_amt_session12', 'consume_amt_session6',
#        'consume_amt_session3', 'consume_amt_session', 'month_avg_use_year',
#        'month_avg_use_month6', 'month_avg_use_month3',
#        'month_avg_use_month6_std2'],
#       dtype='object')

# %%
df2.describe().T
# Out:
#                              count          mean            std          min  \
# id                         10000.0  16891.760500   11923.329983     0.000000
# y                          10000.0      0.199500       0.399644     0.000000
# city                       10000.0     60.699400      42.824365     0.000000
# mar_status                 10000.0      0.675400       0.929796     0.000000
# age                        10000.0     33.778400       7.950498    19.000000
# xaccount_age               10000.0     23.422200      26.014358     1.000000
# cred_limit                 10000.0  28197.198900   36234.316972     1.000000
# this_bill_rate             10000.0      0.482938       0.479739     0.000000
# this_bill_mp               10000.0  10328.012341   16418.660196     0.000000
# last_mp_days               10000.0   6500.546500    4668.516588     1.000000
# six_bill_num               10000.0      5.258700       1.485932     1.000000
# ...

# %%
df5=(df-df.mean(axis=0))/(df.std(axis=0))

# %%
df5.describe()
# Out:
#                  id             y          city    mar_status           age  \
# count  1.000000e+04  1.000000e+04  1.000000e+04  1.000000e+04  1.000000e+04
# mean  -1.168243e-15  8.164847e-14  1.488143e-16 -2.200085e-15  1.986911e-16
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.416698e+00 -4.991937e-01 -1.417403e+00 -7.263956e-01 -1.858802e+00
# 25%   -8.885530e-01 -4.991937e-01 -9.970819e-01 -7.263956e-01 -7.267973e-01
# 50%   -1.633990e-01 -4.991937e-01 -8.638540e-02 -7.263956e-01 -2.236841e-01
# 75%    8.567019e-01 -4.991937e-01  8.243111e-01  1.424613e+00  5.309856e-01
# max    1.937398e+00  2.003030e+00  1.828412e+00  1.424613e+00  5.059004e+00
#
#        xaccount_age    cred_limit  this_bill_rate  this_bill_mp  last_mp_days  \
# count  1.000000e+04  1.000000e+04    1.000000e+04  1.000000e+04  1.000000e+04
# mean  -3.522183e-17 -1.149403e-15    3.216316e-17  2.575501e-15  8.130407e-15
# ...

# %%
#对每一列进行标准化（每个数值在0-1之间）
import numpy as np
import pandas as pd
np.random.seed(1)
df = pd.DataFrame(np.random.randn(4,4)* 4 + 3)

# %%
#方法一
df1=df.apply(lambda x:(x-np.min(x))/(np.max(x)-np.min(x)))  
#方法二
#df2=(df - df.min())/(df.max()-df.min())
# Out:
#   File "<ipython-input-43-ce3cab1b2796>", line 2
#     df1=df.apply(lambda x:(x-np.min(x))/(np.max(x)-np.min(x)))
#                                                                ^
# SyntaxError: invalid character in identifier
